# %%
name=input("Enter your name:")
print("hello ",name)
# Out:
# Enter your name:Namrata
# hello  Namrata

# %%
a=10
if a>5:
    print("a is greater than 5")
else:
    print("a is less than 5")
# Out:
# a is greater than 5

# %%
choice=input("Enter a for hello, Enter b for hi, Enter c for Bye:")
if choice=="a":
    print("hello")
elif choice=="b":
    print("hi")
elif choice=="c":
    print("Bye")
else:
    print("enter valid choice")
# Out:
# Enter a for hello, Enter b for hi, Enter c for Bye:h
# enter valid choice

# %%
print("Enter three unique numbers:")
a=int(input("Enter no1:"))
b=int(input("Enter no2:"))
c=int(input("Enter no3:"))

if a>b:
    if (a>c):
        print("no1 is max")
    else:
        print("no3 is max")
else:
    if b>c:
        print("no2 is max")
    else:
        print("no3 is max")
# Out:
# Enter three unique numbers:
# Enter no1:56
# Enter no2:78
# Enter no3:4
# no2 is max

# %%
for i in range(1,11):
    if i%2==0:
        print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
print(11%2)
# Out:
# 1

# %%
print(10%2)
# Out:
# 0

# %%
a=0
while a<=5:
    print(a)
    a+=1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
l=[10,20]
l.append(23)
print(l)
# Out:
# [10, 20, 23]
